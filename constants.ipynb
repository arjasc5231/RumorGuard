# %%
GRAPH_DIR = './graphs/'
DATASET_DIR = './datasets/'
MODEL_DIR = './models/'
RESULT_DIR = './results/'

SEED_SIZE = 0.01
BATCH_SIZE = 20
SIMUL_NUM = 10000

default_hyper_params = {'epochs':1000, 'lr': 1.0, 'size_coeff':0.1, 'ent_coeff':1}
no_certainty_hyper_params = {'epochs':1000, 'lr': 1.0, 'size_coeff':0.1, 'ent_coeff':0}
no_budget_hyper_params = {'epochs':1000, 'lr': 1.0, 'size_coeff':0, 'ent_coeff':1}

default_layer6_dim128 = [128,128,128,128,128,128]

ABBR = {'Extended_test_LP-50.pkl.gz':'ET', 'Celebrity_test_LP-50.pkl.gz':'CL', 'WannaCry_test_LP-50.pkl.gz':'WC',
        'Extended_test_LP-LT_50.pkl.gz':'ET_LT', 'Celebrity_test_LP-LT_50.pkl.gz':'CL_LT', 'WannaCry_test_LP-50.pkl.gz':'WC_LT',
        'Extended_test_LP-SIR_50.pkl.gz':'ET_SIR', 'Celebrity_test_LP-SIR_50.pkl.gz':'CL_SIR', 'WannaCry_test_LP-SIR_50.pkl.gz':'WC_SIR'
        }
names = ['ET', 'CL', 'WC']

graph_ET_train = 'Extended_train_LP.txt'
graph_CL_train = 'Celebrity_train_LP.txt'
graph_WC_train = 'WannaCry_train_LP.txt'

graph_ET_test = 'Extended_test_LP.txt'
graph_CL_test = 'Celebrity_test_LP.txt'
graph_WC_test = 'WannaCry_test_LP.txt'

ET1000 = 'Extended_train_LP-1000.pkl.gz'
CL1000 = 'Celebrity_train_LP-1000.pkl.gz'
WC1000 = 'WannaCry_train_LP-1000.pkl.gz'
ET_LT1000 = 'Extended_train_LP-LT_1000.pkl.gz'
CL_LT1000 = 'Celebrity_train_LP-LT_1000.pkl.gz'
WC_LT1000 = 'WannaCry_train_LP-LT_1000.pkl.gz'
ET_SIR1000 = 'Extended_train_LP-SIR_1000.pkl.gz'
CL_SIR1000 = 'Celebrity_train_LP-SIR_1000.pkl.gz'
WC_SIR1000 = 'WannaCry_train_LP-SIR_1000.pkl.gz'

ET50 = 'Extended_test_LP-50.pkl.gz'
CL50 = 'Celebrity_test_LP-50.pkl.gz'
WC50 = 'WannaCry_test_LP-50.pkl.gz'
ET_LT50 = 'Extended_test_LP-LT_50.pkl.gz'
CL_LT50 = 'Celebrity_test_LP-LT_50.pkl.gz'
WC_LT50 = 'WannaCry_test_LP-LT_50.pkl.gz'
ET_SIR50 = 'Extended_test_LP-SIR_50.pkl.gz'
CL_SIR50 = 'Celebrity_test_LP-SIR_50.pkl.gz'
WC_SIR50 = 'WannaCry_test_LP-SIR_50.pkl.gz'
datasets = [ET50, CL50, WC50]
datasets_LT = [ET_LT50, CL_LT50, WC_LT50]
datasets_SIR = [ET_SIR50, CL_SIR50, WC_SIR50]

model_ET = 'ET_1000.pt'
model_CL = 'CL_1000.pt'
model_WC = 'WC_1000.pt'
model_ET_LT = 'ET_LT_1000.pt'
model_CL_LT = 'CL_LT_1000.pt'
model_WC_LT = 'WC_LT_1000.pt'
model_ET_SIR = 'ET_SIR_1000.pt'
model_CL_SIR = 'CL_SIR_1000.pt'
model_WC_SIR = 'WC_SIR_1000.pt'
models = [model_ET, model_CL, model_WC]
models_LT = [model_ET_LT, model_CL_LT, model_WC_LT]
models_SIR = [model_ET_SIR, model_CL_SIR, model_WC_SIR]
